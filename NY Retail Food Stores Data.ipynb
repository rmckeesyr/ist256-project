# %%
import pandas as pd
from sodapy import Socrata

# %%
client = Socrata('data.ny.gov',
                  'LZ8n22WcfBkEDojOKGKIG9tsm',
                  username="rmckee@syr.edu",
                  password="Syr@1923")

results = client.get("9a8c-vfzj", county='Onondaga')

results_df = pd.DataFrame.from_records(results)

results_df
# Out:
#        county license_number operation_type estab_type  \
# 0    Onondaga         730036          Store     JAC
# 1    Onondaga         714349          Store     JAC
# 2    Onondaga         702395          Store     JAC
# 3    Onondaga         715202          Store     JAC
# 4    Onondaga         733452          Store     JAC
# ..        ...            ...            ...        ...
# 640  Onondaga         310507          Store     JAC
# 641  Onondaga         311015          Store     A
# 642  Onondaga         310407          Store     JABC
# 643  Onondaga         310654          Store     JABC
# 644  Onondaga         310682          Store     JAC
#
#                            entity_name                 dba_name street_number  \
# 0    NORTH SALINA MEATS & GROCERY INC   NORTH SALINA MEATS & GR           854
# 1    STEWARTS SHOPS CORP                STEWARTS SHOP 391                7667
# 2    NATUR-TYME INC                     NATUR-TYME                       3160
# 3    SKYLINE 1 EXPRESS INC              SKYLINE 1 EXPRESS                 753
# 4    ALGAMAL MOHAMMED A                 ALL IN ONE PIZZA                  302
# ..                                 ...                      ...           ...
# 640  SYRACUSE UNIVERSITY                FW II ERNIE DAVIS HALL            619
# 641  ALDI INC                           ALDI #47                         6633
# 642  PRICE CHOPPER OPERATING CO INC     PRICE CHOPPER 172                2515
# 643  PRICE CHOPPER OPERATING CO INC     PRICE CHOPPER 199                5701
# 644  BRIGHTON GROCERY INC               BRIGHTON GROCERY                  833
#
#                        street_name address_line_2   address_line_3  \
# 0    SALIAN ST
# 1         MORGAN RD
# 2     ERIE BLVD EAST
# 3    JAMES ST
# 4    MALDEN AVENUE
# ..                             ...            ...              ...
# 640          COMSTOCK AVE
# 641   MANLIUS CENTER RD
# 642           ERIE BLVD E
# 643         E CIRCLE DR
# 644  E BRIGHTON AVE
#
#                    city state zip_code square_footage  \
# 0    SYRACUSE              NY    13208              0
# 1    LIVERPOOL             NY    13090           3000
# 2    SYRACUSE              NY    13214           7000
# 3    SYRACUSE              NY    13203              0
# 4    SYRACUSE              NY    13211           2500
# ..                  ...   ...      ...            ...
# 640  SYRACUSE              NY    13244            800
# 641  EAST SYRACUSE         NY    13057           5000
# 642  SYRACUSE              NY    13224         100000
# 643  CICERO                NY    13039          68000
# 644  SYRACUSE              NY    13205           1500
#
#                                               location
# 0    {'human_address': '{"address": "854 SALIAN ST"...
# 1    {'latitude': '43.141736', 'longitude': '-76.20...
# 2    {'latitude': '43.053956', 'longitude': '-76.07...
# 3    {'latitude': '43.055871', 'longitude': '-76.14...
# 4    {'latitude': '43.104667', 'longitude': '-76.13...
# ..                                                 ...
# 640  {'latitude': '43.039624', 'longitude': '-76.13...
# 641  {'latitude': '43.063388', 'longitude': '-76.05...
# 642  {'latitude': '43.054021', 'longitude': '-76.10...
# 643  {'latitude': '43.148251', 'longitude': '-76.12...
# 644  {'latitude': '43.004677', 'longitude': '-76.13...
#
# [645 rows x 15 columns]
